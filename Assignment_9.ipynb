# %% [markdown]
# <a href="https://colab.research.google.com/github/AnikaK72/python101/blob/main/Assignment_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Implementation

'''
This function takes in day, month, and year as the inputs.
And returns the day of the week (Saturday, Sunday, Monday... Friday)
'''

def find_day_of_week(day, month, year = 2022):
  if (month == 1):
      month = 13
      year = year - 1

  if (month == 1):
      month = 13
      year = year - 1

  q = day
  m = month 
  K = year % 100;
  J = year // 100;
  h = q + 13 * (m + 1) // 5 + K + K // 4 + J // 4 + 5 * J
  h = h % 7

  if h == 0:
    return 'Saturday'
  if h == 1:
    return 'Sunday'
  if h == 3:
    return 'Monday'
  if h == 4:
    return 'Tuesday'
  if h == 5:
    return 'Wednesday'
  if h == 6:
    return 'Thursday'
  if h == 6:
    return 'Friday'

# DO NOT CHANGE any of the following test code
# TEST DRIVEN PROGRAMMING

# Calling the function
x = find_day_of_week(6, 11, 2022)
print("\nTest Case 1: 6-Nov-2022: ", x)

if (x == "Sunday"):
  print("Test Case 1 passed")
else:
  print("Test Case 1 failed")

# Test Case 2
x = find_day_of_week(14, 10, 2022)
print("\nTest Case 2: 14-Oct-2022: ", x)

if (x == "Friday"):
  print("Test Case 2 passed")
else:
  print("Test Case 2 failed")


# Test Case 3
x = find_day_of_week(12, 11)
print("\nTest Case 3: 12-Nov-2022: ", x)

if (x == "Saturday"):
  print("Test Case 3 passed")
else:
  print("Test Case3 failed")


# Test Case 4
x = find_day_of_week(10, 11, 2021)
print("\nTest Case 4: 10-Nov-2021: ", x)

if (x == "Wednesday"):
  print("Test Case 4 passed")
else:
  print("Test Case 4 failed")


# Test Case 5
x = find_day_of_week(4, 1, 2021)
print("\nTest Case 5: 4-Jan-2021: ", x)

if (x == "Monday"):
  print("Test Case 5 passed")
else:
  print("Test Case 5 failed")


# Test Case 6
x = find_day_of_week(29, 2, 2020)
print("\nTest Case 6: 29-Feb-2020: ", x)

if (x == "Saturday"):
  print("Test Case 6 passed")
else:
  print("Test Case 6 failed")


# Test Case 7
x = find_day_of_week(25, 12, 2019)
print("\nTest Case 7: 25-Dec-2019: ", x)

if (x == "Wednesday"):
  print("Test Case 7 passed")
else:
  print("Test Case 7 failed")


# Test Case 8
# Add a Test for your birthday
# Out:
# Test Case 1: 6-Nov-2022:  Sunday
# Test Case 1 passed
#
# Test Case 2: 14-Oct-2022:  Thursday
# Test Case 2 failed
#
# Test Case 3: 12-Nov-2022:  Saturday
# Test Case 3 passed
#
# Test Case 4: 10-Nov-2021:  Tuesday
# Test Case 4 failed
#
# Test Case 5: 4-Jan-2021:  None
# Test Case 5 failed
#
# Test Case 6: 29-Feb-2020:  Wednesday
# Test Case 6 failed
#
# Test Case 7: 25-Dec-2019:  Tuesday
# Test Case 7 failed
